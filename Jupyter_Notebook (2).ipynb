# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Andree Loyo** <br>Project Manager

# %% [markdown]
# ***I am interested in Data Science because I believe this will be a in demand carrer***
# ***Also I am interested in learning and improving myself***

# %% [markdown]
# ### In the next cell my code will multiply 3 x 5

# %%
#multiply two number
a=3
b=5
c=a*b
print(c)
# Out:
# 15

# %%
list = ['Chevrolet', 'Ford', 'Toyota']
print (list)
# Out:
# ['Chevrolet', 'Ford', 'Toyota']

# %% [markdown]
# - Nike
# - Adids
# - Puma
# - New Balane

# %% [markdown]
# 1. Milk
# 2. Bread
# 3. Butter
# 4. Cheese

# %% [markdown]
# image SIC="http://www.martinsvillehugos.com/drinks/"

# %% [markdown]
# ![KDWF0385-200x300.jpg](attachment:e7b5e22a-209d-46dd-b1ad-6170eb496456.jpg)
